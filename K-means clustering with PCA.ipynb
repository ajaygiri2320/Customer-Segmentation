# %% [markdown]
# ## ${\textbf{Libraries}}$

# %%
import numpy as np
import pandas as pd
import scipy

#These are the visualization libraries. Matplotlib is standard and is what most people use.
#Seaborn works on top of matplotlib, as we mentioned in the course.
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
#For standardizing features. We'll use the StandardScaler module.
from sklearn.preprocessing import StandardScaler
#Hierarchical clustering with the Sci Py library. We'll use the dendrogram and linkage modules.
from scipy.cluster.hierarchy import dendrogram, linkage
#Sk learn is one of the most widely used libraries for machine learning. We'll use the k means and pca modules.
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
# We need to save the models, which we'll use in the next section. We'll use pickle for that.
import pickle

# %% [markdown]
# ## ${\textbf{Import Data}}$

# %%
# Load the data, contained in the segmentation data csv file.
df_segmentation = pd.read_csv('segmentation data.csv', index_col = 0)

# %% [markdown]
# ## ${\textbf{Explore Data}}$

# %%
# Descriptive analysis of the data set. Here we just look at the data to gain some insight. 
# We do not apply any transformations or changes to the data.
df_segmentation.head()
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
#
#            Settlement size
# ID
# 100000001                2
# 100000002                2
# 100000003                0
# 100000004                1
# 100000005                1

# %%
df_segmentation.describe()
# Out:
#                Sex  Marital status          Age   Education         Income  \
# count  2000.000000     2000.000000  2000.000000  2000.00000    2000.000000
# mean      0.457000        0.496500    35.909000     1.03800  120954.419000
# std       0.498272        0.500113    11.719402     0.59978   38108.824679
# min       0.000000        0.000000    18.000000     0.00000   35832.000000
# 25%       0.000000        0.000000    27.000000     1.00000   97663.250000
# 50%       0.000000        0.000000    33.000000     1.00000  115548.500000
# 75%       1.000000        1.000000    42.000000     1.00000  138072.250000
# max       1.000000        1.000000    76.000000     3.00000  309364.000000
#
#         Occupation  Settlement size
# count  2000.000000      2000.000000
# mean      0.810500         0.739000
# std       0.638587         0.812533
# min       0.000000         0.000000
# 25%       0.000000         0.000000
# 50%       1.000000         1.000000
# 75%       1.000000         1.000000
# max       2.000000         2.000000

# %% [markdown]
# ## ${\textbf{Correlation Estimate}}$

# %%
# Compute Pearson correlation coefficient for the features in our data set.
# The correlation method in pandas, it has the Pearson correlation set as default.
df_segmentation.corr()
# Out:
#                       Sex  Marital status       Age  Education    Income  \
# Sex              1.000000        0.566511 -0.182885   0.244838 -0.195146
# Marital status   0.566511        1.000000 -0.213178   0.374017 -0.073528
# Age             -0.182885       -0.213178  1.000000   0.654605  0.340610
# Education        0.244838        0.374017  0.654605   1.000000  0.233459
# Income          -0.195146       -0.073528  0.340610   0.233459  1.000000
# Occupation      -0.202491       -0.029490  0.108388   0.064524  0.680357
# Settlement size -0.300803       -0.097041  0.119751   0.034732  0.490881
#
#                  Occupation  Settlement size
# Sex               -0.202491        -0.300803
# Marital status    -0.029490        -0.097041
# Age                0.108388         0.119751
# Education          0.064524         0.034732
# Income             0.680357         0.490881
# Occupation         1.000000         0.571795
# Settlement size    0.571795         1.000000

# %%
# We'll plot the correlations using a Heat Map. Heat Maps are a great way to visualize correlations using color coding.
# We use RdBu as a color scheme
# We set the range from -1 to 1, as it is the range of the Pearson Correlation. 
# Otherwise the function infers the boundaries from the input.
# In this case they will be -0,25 to 0,68, as they are the minumum and maximum correlation indeces between our features.
plt.figure(figsize = (12, 9))
s = sns.heatmap(df_segmentation.corr(),
               annot = True, 
               cmap = 'RdBu',
               vmin = -1, 
               vmax = 1)
s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize = 12)
s.set_xticklabels(s.get_xticklabels(), rotation = 90, fontsize = 12)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## ${\textbf{Visualize Raw Data}}$

# %%
# We'll plot the data using the scatter plots for Age & Income.

plt.figure(figsize = (12, 9))
plt.scatter(df_segmentation.loc[:, 'Age'], df_segmentation.loc[:, 'Income'])
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Visualization of raw data')
plt.show()

# %% [markdown]
# ## ${\textbf{Standardization}}$

# %%
# Standardizing data, so that all features have equal weight. This is important for modelling.
# Otherwise, in our case Income would be considered much more important than Education for Instance. 
# We do not know if this is the case, so we would not like to introduce it to our model. 
# This is what is also refered to as bias.
scaler = StandardScaler()
segmentation_std = scaler.fit_transform(df_segmentation)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# ## ${\textbf{Hierarchical Clustering}}$

# %%
# Perform Hierarchical Clustering. The results are returned as a linkage matrix. 
hier_clust = linkage(segmentation_std, method = 'ward')

# %%
# We plot the results from the Hierarchical Clustering using a Dendrogram. 
# We truncate the dendrogram for better readability. The level p shows only the last p merged clusters
# We also omit showing the labels for each point.
plt.figure(figsize = (12,9))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Distance')
dendrogram(hier_clust,
           truncate_mode = 'level', 
           p = 5, 
           show_leaf_counts = True, 
           no_labels = True)
plt.show()

# %% [markdown]
# ## ${\textbf{K-means Clustering}}$

# %%
# Perform K-means clustering. We consider 1 to 10 clusters, so our for loop runs 10 iterations.
# In addition we run our algorithm at many different starting points - k means plus plus. 
# And we set a random state for reproducibility.
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 0)
    kmeans.fit(segmentation_std)
    wcss.append(kmeans.inertia_)

# %%
# Plot the Within Cluster Sum of Squares for the different number of clusters.
# From this plot we choose the number of clusters. 
# We look for a link in the graphic, after which the descent of wcss isn't as pronounced.
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means Clustering')
plt.show()

# %% [markdown]
# ## Since it can be seen that after cluster 4, the descent in wcss isn't much. So, we can can safely assume the number of clusters as 4.

# %%
# We run K-means with a fixed number of clusters. In our case 4.
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)

# %%
# We divide our data into the four clusters.
kmeans.fit(segmentation_std)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=0, tol=0.0001, verbose=0)

# %% [markdown]
# ### ${\textbf{Results}}$

# %%
# We create a new data frame with the original features and add a new column with the assigned clusters for each point.
df_segm_kmeans = df_segmentation.copy()
df_segm_kmeans['Segment K-means'] = kmeans.labels_

# %%
# Calculate mean values for the clusters and create new dataset
df_segm_analysis = df_segm_kmeans.groupby(['Segment K-means']).mean()
df_segm_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.853901        0.997163  28.963121   1.068085
# 1                0.352814        0.019481  35.577922   0.746753
# 2                0.029825        0.173684  35.635088   0.733333
# 3                0.501901        0.692015  55.703422   2.129278
#
#                         Income  Occupation  Settlement size
# Segment K-means
# 0                105759.119149    0.634043         0.422695
# 1                 97859.852814    0.329004         0.043290
# 2                141218.249123    1.271930         1.522807
# 3                158338.422053    1.129278         1.110266

# %%
# Compute the size and proportions of the four clusters
df_segm_analysis['N Obs'] = df_segm_kmeans[['Segment K-means','Sex']].groupby(['Segment K-means']).count()
df_segm_analysis['Prop Obs'] = df_segm_analysis['N Obs'] / df_segm_analysis['N Obs'].sum()

# %%
df_segm_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.853901        0.997163  28.963121   1.068085
# 1                0.352814        0.019481  35.577922   0.746753
# 2                0.029825        0.173684  35.635088   0.733333
# 3                0.501901        0.692015  55.703422   2.129278
#
#                         Income  Occupation  Settlement size  N Obs  Prop Obs
# Segment K-means
# 0                105759.119149    0.634043         0.422695    705    0.3525
# 1                 97859.852814    0.329004         0.043290    462    0.2310
# 2                141218.249123    1.271930         1.522807    570    0.2850
# 3                158338.422053    1.129278         1.110266    263    0.1315

# %% [markdown]
# From the data,
# Segment 0 : we hypothesize that it is highly standard since it has the customers with avg age of ~29 who have moderate income and occupation and lives in small & mid-sized cities (from settlement size)
#
# Segment 1 : we hypothesize that it is fewer-opportunities since it has the customers with avg age of ~35 who have low income & occupation from the other segments and lives in small cities (from settlement size)
#
# Segment 2 : we hypothesize that it is career-focussed since it has the customers with avg age of ~35 who have high income & occupation and lives in big cities (from settlement size)
#
# Segment 3 : we hypothesize that it is Well-off since it has the customers with avg age of ~55 who have high income & occupation and lives in mid-sized & big cities (from settlement size)

# %%
df_segm_analysis.rename({0:'standard',
                         1:'fewer-opportunities',
                         2:'career focused',
                         3:'well-off'})
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means
# standard             0.853901        0.997163  28.963121   1.068085
# fewer-opportunities  0.352814        0.019481  35.577922   0.746753
# career focused       0.029825        0.173684  35.635088   0.733333
# well-off             0.501901        0.692015  55.703422   2.129278
#
#                             Income  Occupation  Settlement size  N Obs  \
# Segment K-means
# standard             105759.119149    0.634043         0.422695    705
# fewer-opportunities   97859.852814    0.329004         0.043290    462
# career focused       141218.249123    1.271930         1.522807    570
# well-off             158338.422053    1.129278         1.110266    263
#
#                      Prop Obs
# Segment K-means
# standard               0.3525
# fewer-opportunities    0.2310
# career focused         0.2850
# well-off               0.1315

# %%
# Add the segment labels to our table
df_segm_kmeans['Labels'] = df_segm_kmeans['Segment K-means'].map({0:'standard',
                                                                 1:'fewer-opportunities',
                                                                 2:'career focused',
                                                                 3:'well-off'})

# %%
# We plot the results from the K-means algorithm. 
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
x_axis = df_segm_kmeans['Age']
y_axis = df_segm_kmeans['Income']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_segm_kmeans['Labels'], palette = ['c', 'r', 'b', 'g'])
plt.title('Segmentation K-means')
plt.show()

# %% [markdown]
# It can be seen that the clusters are not properly separated using the k-means algorithm. So we need to reduce the dimensions in our dataset and choose only meaningful data to form our clusters. To do this, we use the principal component analysis (PCA) to perform dimensionality reduction in our dataset.

# %% [markdown]
# ### ${\textbf{PCA}}$

# %%
# Employ PCA to find a subset of components, which explain the variance in the data.
pca = PCA()

# %%
# Fit PCA with our standardized data.
pca.fit(segmentation_std)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
# The attribute shows how much variance is explained by each of the seven individual components.
pca.explained_variance_ratio_
# Out:
# array([0.35696328, 0.26250923, 0.18821114, 0.0755775 , 0.05716512,
#        0.03954794, 0.02002579])

# %%
# Plot the cumulative variance explained by total number of components.
# On this graph we choose the subset of components we want to keep. 
# Generally, we want to keep around 80 % of the explained variance.
plt.figure(figsize = (12,9))
plt.plot(range(1,8), pca.explained_variance_ratio_.cumsum(), marker = 'o', linestyle = '--')
plt.title('Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
# We choose three components. 3 or 4 seems the right choice according to the previous graph.
# We choose 3 since it explains more than 80% variability in our data.
pca = PCA(n_components = 3)

# %%
#Fit the model the our data with the selected number of components. In our case three.
pca.fit(segmentation_std)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# ### ${\textbf{PCA Results}}$

# %%
# Here we discucss the results from the PCA.
# The components attribute shows the loadings of each component on each of the seven original features.
# The loadings are the correlations between the components and the original features. 
pca.components_
# Out:
# array([[-0.31469524, -0.19170439,  0.32609979,  0.15684089,  0.52452463,
#          0.49205868,  0.46478852],
#        [ 0.45800608,  0.51263492,  0.31220793,  0.63980683,  0.12468314,
#          0.01465779, -0.06963165],
#        [-0.29301261, -0.44197739,  0.60954372,  0.27560461, -0.16566231,
#         -0.39550539, -0.29568503]])

# %%
df_pca_comp = pd.DataFrame(data = pca.components_,
                           columns = df_segmentation.columns.values,
                           index = ['Component 1', 'Component 2', 'Component 3'])
df_pca_comp
# Out:
#                   Sex  Marital status       Age  Education    Income  \
# Component 1 -0.314695       -0.191704  0.326100   0.156841  0.524525
# Component 2  0.458006        0.512635  0.312208   0.639807  0.124683
# Component 3 -0.293013       -0.441977  0.609544   0.275605 -0.165662
#
#              Occupation  Settlement size
# Component 1    0.492059         0.464789
# Component 2    0.014658        -0.069632
# Component 3   -0.395505        -0.295685

# %%
# Heat Map for Principal Components against original features. Again we use the RdBu color scheme and set borders to -1 and 1.
sns.heatmap(df_pca_comp,
            vmin = -1, 
            vmax = 1,
            cmap = 'RdBu',
            annot = True)
plt.yticks([0, 1, 2], 
           ['Component 1', 'Component 2', 'Component 3'],
           rotation = 45,
           fontsize = 9)
plt.show()

# %%
pca.transform(segmentation_std)
# Out:
# array([[ 2.51474593,  0.83412239,  2.1748059 ],
#        [ 0.34493528,  0.59814564, -2.21160279],
#        [-0.65106267, -0.68009318,  2.2804186 ],
#        ...,
#        [-1.45229829, -2.23593665,  0.89657125],
#        [-2.24145254,  0.62710847, -0.53045631],
#        [-1.86688505, -2.45467234,  0.66262172]])

# %%
scores_pca = pca.transform(segmentation_std)

# %% [markdown]
# ### ${\textbf{K-means clustering with PCA}}$

# %%
# We fit K means using the transformed data from the PCA.
wcss = []
for i in range(1,11):
    kmeans_pca = KMeans(n_clusters = i, init = 'k-means++', random_state = 0)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)

# %%
# Plot the Within Cluster Sum of Squares for the K-means PCA model. Here we make a decission about the number of clusters.
# Again it looks like four is the best option.
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means with PCA Clustering')
plt.show()

# %%
# We have chosen four clusters, so we run K-means with number of clusters equals four. 
# Same initializer and random state as before.
kmeans_pca = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)

# %%
# We fit our data with the k-means pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=0, tol=0.0001, verbose=0)

# %% [markdown]
# ### ${\textbf{K-means clustering with PCA Results}}$

# %%
# We create a new data frame with the original features and add the PCA scores and assigned clusters.
df_segm_pca_kmeans = pd.concat([df_segmentation.reset_index(drop = True), pd.DataFrame(scores_pca)], axis = 1)
df_segm_pca_kmeans.columns.values[-3: ] = ['Component 1', 'Component 2', 'Component 3']
# The last column we add contains the pca k-means clustering labels.
df_segm_pca_kmeans['Segment K-means PCA'] = kmeans_pca.labels_

# %%
df_segm_pca_kmeans
# Out:
#       Sex  Marital status  Age  Education  Income  Occupation  \
# 0       0               0   67          2  124670           1
# 1       1               1   22          1  150773           1
# 2       0               0   49          1   89210           0
# 3       0               0   45          1  171565           1
# 4       0               0   53          1  149031           1
# 5       0               0   35          1  144848           0
# 6       0               0   53          1  156495           1
# 7       0               0   35          1  193621           2
# 8       0               1   61          2  151591           0
# 9       0               1   28          1  174646           2
# 10      1               1   25          1  108469           1
# 11      1               1   24          1  127596           1
# 12      1               1   22          1  108687           1
# 13      0               0   60          2   89374           0
# 14      1               1   28          1  102899           1
# 15      1               1   32          1   88428           0
# 16      0               0   53          1  125550           1
# 17      0               0   25          0  157434           1
# 18      1               1   44          2  261952           2
# 19      0               0   31          0  144657           1
# 20      0               0   48          1  118777           1
# 21      0               0   44          1  147511           1
# 22      0               0   48          1   89804           0
# 23      0               0   44          1  134918           1
# 24      0               1   26          1  103667           1
# 25      0               0   36          1   71909           0
# 26      0               1   39          1   68264           0
# 27      1               1   42          2  163025           1
# 28      0               0   34          1  119307           1
# 29      0               0   63          2  175882           1
# ...   ...             ...  ...        ...     ...         ...
# 1970    0               1   27          1  105197           1
# 1971    1               1   25          1  115566           0
# 1972    1               1   34          1  125843           0
# 1973    1               0   24          0   67936           0
# 1974    1               0   34          1  120863           1
# 1975    0               0   42          1   77317           0
# 1976    1               0   38          1   84653           0
# 1977    0               0   42          1   81606           0
# 1978    1               0   35          1  113380           0
# 1979    1               1   27          1  100644           1
# 1980    0               0   25          0   64037           0
# 1981    1               1   23          1  101350           1
# 1982    1               1   34          1  126334           1
# 1983    1               1   28          1  130877           1
# 1984    0               0   21          0  103470           1
# 1985    1               0   32          0  114588           1
# 1986    1               1   21          1  120682           1
# 1987    0               0   25          0   66628           0
# 1988    1               1   35          1  124447           0
# 1989    1               1   25          1  106567           0
# 1990    1               1   31          1   78758           0
# 1991    0               0   54          1  128537           1
# 1992    1               0   51          1  101074           0
# 1993    1               0   38          1   87670           0
# 1994    0               0   45          1  113414           1
# 1995    1               0   47          1  123525           0
# 1996    1               1   27          1  117744           1
# 1997    0               0   31          0   86400           0
# 1998    1               1   24          1   97968           0
# 1999    0               0   25          0   68416           0
#
#       Settlement size  Component 1  Component 2  Component 3  \
# 0                   2     2.514746     0.834122     2.174806
# 1                   2     0.344935     0.598146    -2.211603
# 2                   0    -0.651063    -0.680093     2.280419
# 3                   1     1.714316    -0.579927     0.730731
# 4                   1     1.626745    -0.440496     1.244909
# 5                   0    -0.274734    -0.871070     1.310152
# 6                   1     1.729504    -0.416069     1.212454
# 7                   1     2.510377    -0.751256    -0.504917
# 8                   0     0.419891     1.936115     2.209117
# 9                   0     1.098729     0.111131    -1.306561
# 1996                    1
# 1997                    0
# 1998                    1
# 1999                    0
#
# [2000 rows x 11 columns]

# %% [markdown]
# From the data,
# Segment 0 : we hypothesize that it is highly standard since it has the customers with avg age of ~29 who have moderate income and occupation and lives in small & mid-sized cities (from settlement size)
#
# Segment 1 : we hypothesize that it is fewer-opportunities since it has the customers with avg age of ~35 who have low income & occupation from the other segments and lives in small cities (from settlement size)
#
# Segment 2 : we hypothesize that it is career-focussed since it has the customers with avg age of ~35 who have high income & occupation and lives in big cities (from settlement size)
#
# Segment 3 : we hypothesize that it is Well-off since it has the customers with avg age of ~55 who have high income & occupation and lives in mid-sized & big cities (from settlement size)

# %%
# We calculate the means by segments.
df_segm_pca_kmeans_freq = df_segm_pca_kmeans.groupby(['Segment K-means PCA']).mean()
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# 0                    0.306522        0.095652  35.313043   0.760870
# 1                    0.900289        0.965318  28.878613   1.060694
# 2                    0.505660        0.690566  55.679245   2.128302
# 3                    0.027444        0.168096  35.737564   0.734134
#
#                             Income  Occupation  Settlement size  Component 1  \
# Segment K-means PCA
# 0                     93692.567391    0.252174         0.039130    -1.046406
# 1                    107551.500000    0.677746         0.440751    -1.107019
# 2                    158019.101887    1.120755         1.101887     1.687328
# 3                    141525.826758    1.267581         1.480274     1.372663
#
#                      Component 2  Component 3
# Segment K-means PCA
# 0                      -0.902963     1.003644
# 1                       0.703776    -0.781410
# 2                       2.031200     0.844039
# 3                      -1.046172    -0.248046

# %% [markdown]
# From the data,
#
# Segment 0 : we hypothesize that it is fewer-opportunities since it has the customers with avg age of ~35 who have low income & occupation from the other segments and lives in small cities (from settlement size)
#
# Segment 1 : we hypothesize that it is standard since it has the customers with avg age of ~29 who have moderate income and occupation and lives in small & mid-sized cities (from settlement size)
#
# Segment 2 : we hypothesize that it is Well-off since it has the customers with avg age of ~55 who have high income & occupation and lives in mid-sized & big cities (from settlement size)
#
# Segment 3 : we hypothesize that it is career-focussed since it has the customers with avg age of ~35 who have high income & occupation and lives in big cities (from settlement size)

# %%
# Calculate the size of each cluster and its proportion to the entire data set.
df_segm_pca_kmeans_freq['N Obs'] = df_segm_pca_kmeans[['Segment K-means PCA','Sex']].groupby(['Segment K-means PCA']).count()
df_segm_pca_kmeans_freq['Prop Obs'] = df_segm_pca_kmeans_freq['N Obs'] / df_segm_pca_kmeans_freq['N Obs'].sum()
df_segm_pca_kmeans_freq = df_segm_pca_kmeans_freq.rename({0:'fewer opportunities', 
                                                          1:'standard',
                                                          2:'well-off', 
                                                          3:'career focused'})
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# fewer opportunities  0.306522        0.095652  35.313043   0.760870
# standard             0.900289        0.965318  28.878613   1.060694
# well-off             0.505660        0.690566  55.679245   2.128302
# career focused       0.027444        0.168096  35.737564   0.734134
#
#                             Income  Occupation  Settlement size  Component 1  \
# Segment K-means PCA
# fewer opportunities   93692.567391    0.252174         0.039130    -1.046406
# standard             107551.500000    0.677746         0.440751    -1.107019
# well-off             158019.101887    1.120755         1.101887     1.687328
# career focused       141525.826758    1.267581         1.480274     1.372663
#
#                      Component 2  Component 3  N Obs  Prop Obs
# Segment K-means PCA
# fewer opportunities    -0.902963     1.003644    460    0.2300
# standard                0.703776    -0.781410    692    0.3460
# well-off                2.031200     0.844039    265    0.1325
# career focused         -1.046172    -0.248046    583    0.2915

# %%
df_segm_pca_kmeans['Legend'] = df_segm_pca_kmeans['Segment K-means PCA'].map({0:'fewer opportunities', 
                                                          1:'standard',
                                                          2:'well-off', 
                                                          3:'career focused'})

# %%
# Plot data by PCA components. The Y axis is the first component, X axis is the second.
x_axis = df_segm_pca_kmeans['Component 2']
y_axis = df_segm_pca_kmeans['Component 1']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_segm_pca_kmeans['Legend'], palette = ['g', 'r', 'c', 'm'])
plt.title('Clusters by PCA Components')
plt.show()

# %% [markdown]
# It can be seen that the data is now been properly clustered with little overlapping

# %% [markdown]
# ### ${\textbf{Data Export}}$

# %%
# We save the objects we'll need in the Purchase Analytics part of the course. We export them as pickle objects.
# We need the scaler, pca and kmeans_pca objects to preprocess and segment the purchase data set.
pickle.dump(scaler, open('scaler.pickle', 'wb'))

# %%
pickle.dump(pca, open('pca.pickle', 'wb'))

# %%
pickle.dump(kmeans_pca, open('kmeans_pca.pickle', 'wb'))
